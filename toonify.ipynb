# %%
from white_box_cartoonizer.cartoonize import WB_Cartoonize
import cv2
from matplotlib import pyplot as plt
img = cv2.imread("./static/sample_images/rajat.jpeg")

# %%
wb_cartoonizer = WB_Cartoonize("white_box_cartoonizer/saved_models/", 0)
img = wb_cartoonizer.infer(img)
plt.imshow(img)
cv2.imwrite("rajat_cartoon.jpg", img)
# Out:
# INFO:tensorflow:Restoring parameters from white_box_cartoonizer/saved_models/model-33999
# Weights successfully loaded
# True
